# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('../data/train.csv')
train.head(3)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0

# %%
weather = pd.read_csv('../data/weather.csv')
weather.head(3)
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
#
# [3 rows x 22 columns]

# %%
# Checking nulls
train.isnull().sum()
# Out:
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64

# %%
train.shape
# Out:
# (10506, 12)

# %%
train.dtypes
# Out:
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# dtype: object

# %%
train.describe().T
# Out:
#                    count       mean        std        min        25%  \
# Block            10506.0  35.687797  24.339468  10.000000  12.000000
# Latitude         10506.0  41.841139   0.112742  41.644612  41.732984
# Longitude        10506.0 -87.699908   0.096514 -87.930995 -87.760070
# AddressAccuracy  10506.0   7.819532   1.452921   3.000000   8.000000
# NumMosquitos     10506.0  12.853512  16.133816   1.000000   2.000000
# WnvPresent       10506.0   0.052446   0.222936   0.000000   0.000000
#
#                        50%        75%        max
# Block            33.000000  52.000000  98.000000
# Latitude         41.846283  41.954690  42.017430
# Longitude       -87.694991 -87.627796 -87.531635
# AddressAccuracy   8.000000   9.000000   9.000000
# NumMosquitos      5.000000  17.000000  50.000000
# WnvPresent        0.000000   0.000000   1.000000

# %%
train["Date"] = pd.to_datetime(train["Date"], infer_datetime_format=True)

# %%
train['Address'] = train['Address'].astype('category')
train['Species'] = train['Species'].astype('category')
train['Street'] = train['Street'].astype('category')
train['Trap'] = train['Trap'].astype('category')
train['AddressNumberAndStreet'] = train['AddressNumberAndStreet'].astype('category')

# %%
train.dtypes
# Out:
# Date                      datetime64[ns]
# Address                         category
# Species                         category
# Block                              int64
# Street                          category
# Trap                            category
# AddressNumberAndStreet          category
# Latitude                         float64
# Longitude                        float64
# AddressAccuracy                    int64
# NumMosquitos                       int64
# WnvPresent                         int64
# dtype: object

# %%
train.WnvPresent.sum()
# Out:
# 551

# %%
train.WnvPresent.mean()
# Out:
# 0.05244622120692937

# %%
mospecies = pd.get_dummies(train.Species).sum()
mospecies
# Out:
# CULEX ERRATICUS              1
# CULEX PIPIENS             2699
# CULEX PIPIENS/RESTUANS    4752
# CULEX RESTUANS            2740
# CULEX SALINARIUS            86
# CULEX TARSALIS               6
# CULEX TERRITANS            222
# dtype: int64

# %%
train.groupby('Species')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# Species
# CULEX PIPIENS             0.088922
# CULEX PIPIENS/RESTUANS    0.055135
# CULEX RESTUANS            0.017883
# CULEX TERRITANS           0.000000
# CULEX TARSALIS            0.000000
# CULEX SALINARIUS          0.000000
# CULEX ERRATICUS           0.000000
# Name: WnvPresent, dtype: float64

# %%
trap = pd.get_dummies(train.Trap).sum()
trap
# Out:
# T001     15
# T002    185
# T003    122
# T004     12
# T005     14
# T006     24
# T007     23
# T008    139
# T009    111
# T011    133
# T012    105
# T013    104
# T014     30
# T015     35
# T016     66
# T017     78
# T018     63
# T019     23
# T025     27
# T027     93
# T028    117
# T030    126
# T031    146
# T033     97
# T034     17
# T035     72
# T036     24
# T037     29
# T039     80
# T040      2
#        ...
# T160     91
# T161     26
# T162     21
# T200    129
# T206     21
# T209    130
# T212    152
# T215     45
# T218     74
# T219     21
# T220     98
# T221    112
# T222     60
# T223     87
# T224     54
# T225    103
# T226     77
# T227     78
# T228     62
# T229      8
# T230     65
# T231     42
# T232     50
# T233     50
# T235     62
# T236     33
# T237      3
# T238      7
# T900    750
# T903    140
# Length: 136, dtype: int64

# %%
train.groupby('Trap')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# Trap
# T143     0.193548
# T006     0.166667
# T005     0.142857
# T233     0.140000
# T014     0.133333
# T096     0.120000
# T003     0.114754
# T015     0.114286
# T235     0.112903
# T054C    0.111111
# T230     0.107692
# T225     0.106796
# T016     0.106061
# T223     0.103448
# T070     0.100000
# T002     0.097297
# T228     0.096774
# T013     0.096154
# T154     0.095238
# T231     0.095238
# T086     0.093023
# T107     0.090909
# T900     0.088000
# T045     0.085714
# T011     0.082707
# T082     0.081633
# T009     0.081081
# T221     0.080357
# T061     0.077670
# T028     0.076923
#            ...
# T238     0.000000
# T025     0.000000
# T019     0.000000
# T219     0.000000
# T129     0.000000
# T040     0.000000
# T078     0.000000
# T100     0.000000
# T099     0.000000
# T141     0.000000
# T094B    0.000000
# T092     0.000000
# T146     0.000000
# T088     0.000000
# T148     0.000000
# T149     0.000000
# T150     0.000000
# T076     0.000000
# ...

# %%
train.groupby('NumMosquitos')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# NumMosquitos
# 31    0.234043
# 38    0.228571
# 39    0.224490
# 48    0.222222
# 33    0.194444
# 28    0.186047
# 37    0.180328
# 40    0.178571
# 42    0.172414
# 36    0.170213
# 47    0.162162
# 41    0.161290
# 30    0.159091
# 43    0.153846
# 27    0.149254
# 23    0.144928
# 49    0.142857
# 45    0.142857
# 21    0.141176
# 24    0.140351
# 29    0.125000
# 13    0.122699
# 44    0.120000
# 18    0.119565
# 16    0.117188
# 35    0.116279
# 46    0.116279
# 20    0.113924
# 22    0.107143
# 50    0.105986
# 26    0.105263
# 32    0.102564
# 25    0.100000
# 15    0.098214
# 34    0.096774
# 12    0.090909
# 17    0.084112
# 9     0.071730
# 19    0.069767
# 14    0.066667
# 10    0.053398
# 11    0.047059
# 8     0.045082
# 7     0.039877
# 5     0.038855
# 6     0.025126
# 4     0.020236
# 3     0.016741
# 1     0.008669
# 2     0.005385
# Name: WnvPresent, dtype: float64

# %%
train.groupby(['NumMosquitos'])['WnvPresent'].mean().plot.bar()

# %%
train.groupby(train['AddressAccuracy']).sum()
# Out:
#                   Block       Latitude      Longitude  NumMosquitos  \
# AddressAccuracy
# 3                  3913    3810.908374   -7974.311618           402
# 5                 35562   75410.075051 -158326.915414         43093
# 8                194353  193643.993596 -405827.856718         45797
# 9                141108  166718.032357 -349246.149522         45747
#
#                  WnvPresent
# AddressAccuracy
# 3                         1
# 5                        94
# 8                       241
# 9                       215

# %%
train.groupby('NumMosquitos')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# NumMosquitos
# 31    0.234043
# 38    0.228571
# 39    0.224490
# 48    0.222222
# 33    0.194444
# 28    0.186047
# 37    0.180328
# 40    0.178571
# 42    0.172414
# 36    0.170213
# 47    0.162162
# 41    0.161290
# 30    0.159091
# 43    0.153846
# 27    0.149254
# 23    0.144928
# 49    0.142857
# 45    0.142857
# 21    0.141176
# 24    0.140351
# 29    0.125000
# 13    0.122699
# 44    0.120000
# 18    0.119565
# 16    0.117188
# 35    0.116279
# 46    0.116279
# 20    0.113924
# 22    0.107143
# 50    0.105986
# 26    0.105263
# 32    0.102564
# 25    0.100000
# 15    0.098214
# 34    0.096774
# 12    0.090909
# 17    0.084112
# 9     0.071730
# 19    0.069767
# 14    0.066667
# 10    0.053398
# 11    0.047059
# 8     0.045082
# 7     0.039877
# 5     0.038855
# 6     0.025126
# 4     0.020236
# 3     0.016741
# 1     0.008669
# 2     0.005385
# Name: WnvPresent, dtype: float64

# %%
#sns.set()
#plt.rcParams['figure.figsize'] = [15, 10]
#sns.set(font_scale=2)

# %%
sns.pairplot(train)

# %%
species1 = pd.DataFrame(train['Species'].value_counts()).reset_index()

# %%
species1 = pd.merge(species1, pd.DataFrame(train[train['WnvPresent']==1]['Species'].value_counts()).reset_index(), on='index')

# %%
species1.columns = ['species', 'num_observations', 'obs_w_wnv']

# %%
sns.stripplot(x="species", y="num_observations", data=species1)
sns.stripplot(x="species", y="obs_w_wnv", data=species1)

# %%
species1
# Out:
#                   species  num_observations  obs_w_wnv
# 0  CULEX PIPIENS/RESTUANS              4752        262
# 1          CULEX RESTUANS              2740         49
# 2           CULEX PIPIENS              2699        240
# 3         CULEX TERRITANS               222          0
# 4        CULEX SALINARIUS                86          0
# 5          CULEX TARSALIS                 6          0
# 6         CULEX ERRATICUS                 1          0

# %%
train['Species'] = train['Species'].str.replace('CULEX ', '')

# %%
sns.set(font_scale=1.5)
sns.countplot(x='Species', hue='WnvPresent', data=train)
plt.legend(['West Nile Virus not present', 'West Nile Virus present'], loc=1)
plt.ylabel('Number of Species in Traps')
plt.title('West Nile Virus by Species');

# %%
plt.figure(figsize=(6,5))
plt.hist(train['WnvPresent'], bins=3)
plt.title('West Nile Virus Presence in Mosquitos')
plt.xlabel('WNV presence')
plt.xticks([0,1]);

# %%
train['Month'] = pd.DatetimeIndex(train['Date']).month

# %%
mos_plot = sns.pointplot(x='Month', y="NumMosquitos", hue='Species', data=train)
mos_plot.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Number of Mosquitos in Trap')
plt.legend(['Culex Pipiens', 'Culex Pipiens/Restuans', 'Culex Restuans'])

# %%
train[train.NumMosquitos == 50]
train.groupby(['Date', 'Trap', 'Species'], as_index=False)['NumMosquitos'].sum().sort_values('NumMosquitos', ascending=False).head()
# Out:
#             Date  Trap  Species  NumMosquitos
# 16759 2007-08-16  T115  PIPIENS        2532.0
# 8191  2007-07-25  T115  PIPIENS        2356.0
# 21519 2007-08-28  T115  PIPIENS        2207.0
# 13931 2007-08-08  T138  PIPIENS        1658.0
# 23423 2007-09-05  T115  PIPIENS        1648.0

# %%
train = pd.merge(train, train.groupby(['Date', 'Trap', 'Species'], as_index=False)['NumMosquitos'].sum(), on=['Date', 'Trap', 'Species'])

# %%
train.head(3)
# Out:
#         Date                                            Address  \
# 0 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
#
#             Species  Block           Street  Trap  \
# 0  PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          RESTUANS     41   N OAK PARK AVE  T002
# 2          RESTUANS     62    N MANDELL AVE  T007
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
#
#    NumMosquitos_x  WnvPresent  Month  NumMosquitos_y
# 0               1           0      5             1.0
# 1               1           0      5             1.0
# ...

# %%
train.columns = ['Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
       'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
       'NumMosquitos', 'WnvPresent', 'Month', 'Tot_Mos_Species_Day']

# %%
train['Year'] = train['Date'].dt.year

# %%
trap_mos=train.groupby(['AddressNumberAndStreet', 'Trap'], as_index=False)['WnvPresent', 'NumMosquitos'].sum().sort_values('WnvPresent')

# %%
train[train['Year']==2009].groupby('Date', as_index=False)['WnvPresent'].sum()
# Out:
#          Date  WnvPresent
# 0  2009-05-28           0
# 1  2009-06-02           0
# 2  2009-06-03           0
# 3  2009-06-05           0
# 4  2009-06-12           0
# 5  2009-06-15           0
# 6  2009-06-19           0
# 7  2009-06-22           0
# 8  2009-06-26           0
# 9  2009-06-29           0
# 10 2009-07-06           0
# 11 2009-07-10           0
# 12 2009-07-13           0
# 13 2009-07-17           0
# 14 2009-07-24           2
# 15 2009-07-27           2
# 16 2009-07-31           1
# 17 2009-08-07           0
# 18 2009-08-13           2
# 19 2009-08-25           7
# 20 2009-08-27           0
# 21 2009-09-03           1
# 22 2009-09-14           3
# 23 2009-09-17           0
# 24 2009-09-25           1
# 25 2009-10-01           0

# %%
train[['NumMosquitos']].sum()
# Out:
# NumMosquitos    135039
# dtype: int64

# %%
trap_mos['percent_virus'] = trap_mos['WnvPresent']/trap_mos['NumMosquitos']

# %%
trap_mos.sort_values('WnvPresent', ascending=False).head(10)
# Out:
#                       AddressNumberAndStreet  Trap  WnvPresent  NumMosquitos  \
# 1086      1000  W OHARE AIRPORT, Chicago, IL  T900        66.0       15386.0
# 2530           1200  S DOTY AVE, Chicago, IL  T115        41.0       21668.0
# 9793       4100  N OAK PARK AVE, Chicago, IL  T002        18.0        3710.0
# 630    1000  S STONY ISLAND AVE, Chicago, IL  T138        16.0        9936.0
# 10746     4600  N MILWAUKEE AVE, Chicago, IL  T003        14.0        1346.0
# 17529       8200  S KOSTNER AVE, Chicago, IL  T225        11.0        2014.0
# 8169     3600  N PITTSBURGH AVE, Chicago, IL  T011        11.0        1311.0
# 6203           2400  E 105TH ST, Chicago, IL  T128        11.0        3315.0
# 15647        7000  N MOSELL AVE, Chicago, IL  T008        10.0        2668.0
# 1223              1000  W OHARE, Chicago, IL  T903        10.0        2327.0
#
#        percent_virus
# 1086        0.004290
# 2530        0.001892
# 9793        0.004852
# 630         0.001610
# ...

# %%
trap_mos.sort_values('percent_virus', ascending=False).head(10)
# Out:
#                     AddressNumberAndStreet  Trap  WnvPresent  NumMosquitos  \
# 13468       6000  W ROSCOE ST, Chicago, IL  T005         2.0          50.0
# 13197    6000  N AVONDALE AVE, Chicago, IL  T006         4.0         107.0
# 14913    6500  N OAK PARK AVE, Chicago, IL  T143         6.0         230.0
# 16741      7900  W FOSTER AVE, Chicago, IL  T015         4.0         169.0
# 17080         8100  E 91ST ST, Chicago, IL  T107         2.0          86.0
# 12153         5200  S NORDICA, Chicago, IL  T070         2.0          90.0
# 10226         4200  W 31ST ST, Chicago, IL  T036         1.0          52.0
# 9472       4000  N AUSTIN AVE, Chicago, IL  T142         1.0          58.0
# 15198  6600  S KILPATRICK AVE, Chicago, IL  T156         1.0          61.0
# 9716      4000  S DEARBORN ST, Chicago, IL  T081         3.0         207.0
#
#        percent_virus
# 13468       0.040000
# 13197       0.037383
# 14913       0.026087
# 16741       0.023669
# 17080       0.023256
# ...

# %%
train[train.Trap == 'T230'].groupby('Year')['NumMosquitos', 'WnvPresent'].sum()
# Out:
#       NumMosquitos  WnvPresent
# Year
# 2009            24           1
# 2011           227           1
# 2013           393           5

# %%
train[train['Date']=='2009-06-22'].head()
# Out:
#            Date                                            Address  \
# 4272 2009-06-22        1100 Roosevelt Road, Chicago, IL 60608, USA
# 4273 2009-06-22        1100 Roosevelt Road, Chicago, IL 60608, USA
# 4274 2009-06-22  ORD Terminal 5, O'Hare International Airport, ...
# 4275 2009-06-22  ORD Terminal 5, O'Hare International Airport, ...
# 4276 2009-06-22  ORD Terminal 5, O'Hare International Airport, ...
#
#                Species  Block            Street  Trap  \
# 4272  PIPIENS/RESTUANS     11       W ROOSEVELT  T048
# 4273          RESTUANS     11       W ROOSEVELT  T048
# 4274  PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 4275  PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
# 4276  PIPIENS/RESTUANS     10   W OHARE AIRPORT  T900
#
#                   AddressNumberAndStreet   Latitude  Longitude  \
# 4272      1100  W ROOSEVELT, Chicago, IL  41.867108 -87.654224
# 4273      1100  W ROOSEVELT, Chicago, IL  41.867108 -87.654224
# ...

# %%
train['Year'].value_counts()
# Out:
# 2007    3811
# 2013    2392
# 2009    2249
# 2011    2054
# Name: Year, dtype: int64

# %%
by_day = train[train['Year']==2007].groupby('Date', as_index=False)['Tot_Mos_Species_Day'].sum()
by_day.plot('Date', figsize=(15,8))

# %%
by_day = train[train['Year']==2009].groupby('Date', as_index=False)['Tot_Mos_Species_Day'].sum()
by_day.plot('Date', figsize=(15,8))

# %%
by_day = train[train['Year']==2011].groupby('Date', as_index=False)['Tot_Mos_Species_Day'].sum()
by_day.plot('Date', figsize=(15,8))

# %%
by_day = train[train['Year']==2013].groupby('Date', as_index=False)['Tot_Mos_Species_Day'].sum()
by_day.plot('Date', figsize=(15,8))

# %%
train['Month'] = train['Date'].dt.month
train['Day'] = train['Date'].dt.day
train['day_of_year']= train['Date'].dt.dayofyear

# %%
mos_year = sns.pointplot(x='Month', y="NumMosquitos", hue="Year", data=train.groupby(['Year', 'Month'], as_index=False)['NumMosquitos'].mean(),)
mos_year.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Number of Mosquitos in Trap')
# Out:
# Text(0,0.5,'Average Number of Mosquitos in Trap')

# %%
wnv_year = sns.pointplot(x='Month', y="WnvPresent", hue="Year", data=train.groupby(['Year', 'Month'], as_index=False)['WnvPresent'].mean(),)
wnv_year.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Cases of WNV in Trap')
# Out:
# Text(0,0.5,'Average Cases of WNV in Trap')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1 = sns.pointplot(x='Month', y="NumMosquitos", hue="Year", data=train.groupby(['Year', 'Month'], as_index=False)['NumMosquitos'].mean(),)
plt.ylabel('Average Number of Mosquitos in Trap')
ax2 = ax1.twinx()
ax2 = sns.pointplot(x='Month', y="WnvPresent", hue="Year", linestyles='-.', data=train.groupby(['Year', 'Month'], as_index=False)['WnvPresent'].mean(),)
ax1.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Cases of WNV in Trap')
# Out:
# Text(0,0.5,'Average Cases of WNV in Trap')

# %%
train.groupby('Year')['Trap'].count()
# Out:
# Year
# 2007    3811
# 2009    2249
# 2011    2054
# 2013    2392
# Name: Trap, dtype: int64

# %%
sns.set(font_scale=2.0)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1 = sns.pointplot(x='Month', y="NumMosquitos", data=train.groupby(['Month'], as_index=False)['NumMosquitos'].mean(),)
plt.ylabel('Average Number of Mosquitos in Trap')
plt.legend(['Number of Mosquitos'], loc=2)
ax2 = ax1.twinx()
ax2 = sns.pointplot(x='Month', y="WnvPresent", linestyles='-.', color='r', data=train.groupby(['Month'], as_index=False)['WnvPresent'].mean(),)
ax1.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Cases of WNV in Trap')
plt.legend(['Cases of West Nile Virus'], loc=1)
