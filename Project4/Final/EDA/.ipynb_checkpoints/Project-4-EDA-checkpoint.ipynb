# %%
# https://towardsdatascience.com/a-go-at-kaggle-723447f8d95f

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/train.csv')

# %%
df_2 = pd.read_csv('../data/weather.csv')
df_2.tail()
# Out:
#       Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 2939        2  2014-10-29    49    40   45      M        34      42   20    0
# 2940        1  2014-10-30    51    32   42     -4        34      40   23    0
# 2941        2  2014-10-30    53    37   45      M        35      42   20    0
# 2942        1  2014-10-31    47    33   40     -6        25      33   25    0
# 2943        2  2014-10-31    49    34   42      M        29      36   23    0
#
#         ...      CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 2939    ...                  M      M        M        0.00       29.42
# 2940    ...                  0      M      0.0        0.00       29.34
# 2941    ...           RA     M      M        M           T       29.41
# 2942    ...        RA SN     0      M      0.1        0.03       29.49
# 2943    ...     RA SN BR     M      M        M        0.04       29.54
#
#      SeaLevel ResultSpeed ResultDir  AvgSpeed
# ...

# %%
df_2.shape
# Out:
# (2944, 22)

# %%
df_2.columns
# Out:
# Index(['Station', 'Date', 'Tmax', 'Tmin', 'Tavg', 'Depart', 'DewPoint',
#        'WetBulb', 'Heat', 'Cool', 'Sunrise', 'Sunset', 'CodeSum', 'Depth',
#        'Water1', 'SnowFall', 'PrecipTotal', 'StnPressure', 'SeaLevel',
#        'ResultSpeed', 'ResultDir', 'AvgSpeed'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
df.shape
# Out:
# (10506, 12)

# %%
df.WnvPresent.sum()
# Out:
# 551

# %%
df.WnvPresent.mean()
# Out:
# 0.05244622120692937

# %%
df.shape
# Out:
# (10506, 12)

# %%
species = pd.get_dummies(df.Species).sum()

# %%
species
# Out:
# CULEX ERRATICUS              1
# CULEX PIPIENS             2699
# CULEX PIPIENS/RESTUANS    4752
# CULEX RESTUANS            2740
# CULEX SALINARIUS            86
# CULEX TARSALIS               6
# CULEX TERRITANS            222
# dtype: int64

# %%
df.groupby('Species')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# Species
# CULEX PIPIENS             0.088922
# CULEX PIPIENS/RESTUANS    0.055135
# CULEX RESTUANS            0.017883
# CULEX TERRITANS           0.000000
# CULEX TARSALIS            0.000000
# CULEX SALINARIUS          0.000000
# CULEX ERRATICUS           0.000000
# Name: WnvPresent, dtype: float64

# %%
trap = pd.get_dummies(df.Trap).sum()

trap
# Out:
# T001     15
# T002    185
# T003    122
# T004     12
# T005     14
# T006     24
# T007     23
# T008    139
# T009    111
# T011    133
# T012    105
# T013    104
# T014     30
# T015     35
# T016     66
# T017     78
# T018     63
# T019     23
# T025     27
# T027     93
# T028    117
# T030    126
# T031    146
# T033     97
# T034     17
# T035     72
# T036     24
# T037     29
# T039     80
# T040      2
#        ...
# T160     91
# T161     26
# T162     21
# T200    129
# T206     21
# T209    130
# T212    152
# T215     45
# T218     74
# T219     21
# T220     98
# T221    112
# T222     60
# T223     87
# T224     54
# T225    103
# T226     77
# T227     78
# T228     62
# T229      8
# T230     65
# T231     42
# T232     50
# T233     50
# T235     62
# T236     33
# T237      3
# T238      7
# T900    750
# T903    140
# Length: 136, dtype: int64

# %%
df.groupby('Trap')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# Trap
# T143     0.193548
# T006     0.166667
# T005     0.142857
# T233     0.140000
# T014     0.133333
# T096     0.120000
# T003     0.114754
# T015     0.114286
# T235     0.112903
# T054C    0.111111
# T230     0.107692
# T225     0.106796
# T016     0.106061
# T223     0.103448
# T070     0.100000
# T002     0.097297
# T228     0.096774
# T013     0.096154
# T154     0.095238
# T231     0.095238
# T086     0.093023
# T107     0.090909
# T900     0.088000
# T045     0.085714
# T011     0.082707
# T082     0.081633
# T009     0.081081
# T221     0.080357
# T061     0.077670
# T028     0.076923
#            ...
# T238     0.000000
# T025     0.000000
# T019     0.000000
# T219     0.000000
# T129     0.000000
# T040     0.000000
# T078     0.000000
# T100     0.000000
# T099     0.000000
# T141     0.000000
# T094B    0.000000
# T092     0.000000
# T146     0.000000
# T088     0.000000
# T148     0.000000
# T149     0.000000
# T150     0.000000
# T076     0.000000
# ...

# %%
df.groupby('NumMosquitos')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# NumMosquitos
# 31    0.234043
# 38    0.228571
# 39    0.224490
# 48    0.222222
# 33    0.194444
# 28    0.186047
# 37    0.180328
# 40    0.178571
# 42    0.172414
# 36    0.170213
# 47    0.162162
# 41    0.161290
# 30    0.159091
# 43    0.153846
# 27    0.149254
# 23    0.144928
# 49    0.142857
# 45    0.142857
# 21    0.141176
# 24    0.140351
# 29    0.125000
# 13    0.122699
# 44    0.120000
# 18    0.119565
# 16    0.117188
# 35    0.116279
# 46    0.116279
# 20    0.113924
# 22    0.107143
# 50    0.105986
# 26    0.105263
# 32    0.102564
# 25    0.100000
# 15    0.098214
# 34    0.096774
# 12    0.090909
# 17    0.084112
# 9     0.071730
# 19    0.069767
# 14    0.066667
# 10    0.053398
# 11    0.047059
# 8     0.045082
# 7     0.039877
# 5     0.038855
# 6     0.025126
# 4     0.020236
# 3     0.016741
# 1     0.008669
# 2     0.005385
# Name: WnvPresent, dtype: float64

# %%
1 - df['WnvPresent'].mean()
# Out:
# 0.9475537787930707

# %%
df.groupby(df['AddressAccuracy']).sum()

# https://stackoverflow.com/questions/2859705/google-maps-api-geocoding-accuracy-chart
# Out:
#                   Block       Latitude      Longitude  NumMosquitos  \
# AddressAccuracy
# 3                  3913    3810.908374   -7974.311618           402
# 5                 35562   75410.075051 -158326.915414         43093
# 8                194353  193643.993596 -405827.856718         45797
# 9                141108  166718.032357 -349246.149522         45747
#
#                  WnvPresent
# AddressAccuracy
# 3                         1
# 5                        94
# 8                       241
# 9                       215

# %%
df_spray = pd.read_csv('../data/spray.csv')
df_spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
pd.value_counts(df_spray['Latitude'])
# Out:
# 41.986460    541
# 41.995396     11
# 41.982772     10
# 41.994484      9
# 41.985652      9
# 41.984884      8
# 41.993524      8
# 41.996932      8
# 41.984068      8
# 41.995012      7
# 41.994436      7
# 41.992660      7
# 41.986372      7
# 41.993332      7
# 41.993428      7
# 41.992612      6
# 41.996500      6
# 41.992372      6
# 41.996020      6
# 41.996980      6
# 41.993476      6
# 41.948470      5
# 41.982676      5
# 41.983588      5
# 41.996884      5
# 41.982820      5
# 41.988196      5
# 41.985268      5
# 41.993380      5
# 41.989828      5
#             ...
# 41.931488      1
# 41.882943      1
# 41.941743      1
# 41.733185      1
# 41.954487      1
# 41.735252      1
# 41.927697      1
# 41.784140      1
# 41.973953      1
# 41.903232      1
# 41.738012      1
# 41.946202      1
# 41.891492      1
# 41.893735      1
# 41.901985      1
# 41.937478      1
# 41.723147      1
# 41.949540      1
# 41.968763      1
# 41.718738      1
# 41.957280      1
# ...

# %%
pd.value_counts(df_spray['Longitude'])
# Out:
# -87.794225    541
# -87.806911      9
# -87.806863      9
# -87.816751      7
# -87.805711      6
# -87.805615      6
# -87.810415      5
# -87.808351      5
# -87.811567      5
# -87.813727      5
# -87.813199      5
# -87.811855      5
# -87.806959      5
# -87.814111      4
# -87.798775      4
# -87.810319      4
# -87.803695      4
# -87.705312      4
# -87.808255      4
# -87.710883      4
# -87.812767      4
# -87.809407      4
# -87.811903      4
# -87.815983      4
# -87.815188      4
# -87.799762      3
# -87.812017      3
# -88.095143      3
# -87.770608      3
# -87.733588      3
#              ...
# -87.741028      1
# -87.769603      1
# -87.800045      1
# -87.804170      1
# -87.811397      1
# -87.767268      1
# -87.808390      1
# -87.620657      1
# -87.685887      1
# -87.817423      1
# -87.792414      1
# -87.712677      1
# -87.706483      1
# -87.708160      1
# -87.612317      1
# -87.680170      1
# -87.684527      1
# -87.808737      1
# -87.818067      1
# ...

# %%
# df.Latitude = df.Latitude.apply(str)

# df.Longitude = df.Longitude.apply(str)

# df['location'] = df[['Latitude', 'Longitude']].apply(lambda x: ''.join(x), axis=1)

# %%
df.groupby('NumMosquitos')['WnvPresent'].mean().sort_values(ascending=False)
# Out:
# NumMosquitos
# 31    0.234043
# 38    0.228571
# 39    0.224490
# 48    0.222222
# 33    0.194444
# 28    0.186047
# 37    0.180328
# 40    0.178571
# 42    0.172414
# 36    0.170213
# 47    0.162162
# 41    0.161290
# 30    0.159091
# 43    0.153846
# 27    0.149254
# 23    0.144928
# 49    0.142857
# 45    0.142857
# 21    0.141176
# 24    0.140351
# 29    0.125000
# 13    0.122699
# 44    0.120000
# 18    0.119565
# 16    0.117188
# 35    0.116279
# 46    0.116279
# 20    0.113924
# 22    0.107143
# 50    0.105986
# 26    0.105263
# 32    0.102564
# 25    0.100000
# 15    0.098214
# 34    0.096774
# 12    0.090909
# 17    0.084112
# 9     0.071730
# 19    0.069767
# 14    0.066667
# 10    0.053398
# 11    0.047059
# 8     0.045082
# 7     0.039877
# 5     0.038855
# 6     0.025126
# 4     0.020236
# 3     0.016741
# 1     0.008669
# 2     0.005385
# Name: WnvPresent, dtype: float64

# %%
mosq = df[df['NumMosquitos'] == 50]
mosq.shape
# Out:
# (1019, 12)

# %%
mosq[mosq['WnvPresent'] == 1]
# Out:
#              Date                                            Address  \
# 553    2007-07-18     3800 East 115th Street, Chicago, IL 60617, USA
# 603    2007-07-25                South Doty Avenue, Chicago, IL, USA
# 611    2007-07-25                South Doty Avenue, Chicago, IL, USA
# 618    2007-07-25                South Doty Avenue, Chicago, IL, USA
# 660    2007-07-25                South Doty Avenue, Chicago, IL, USA
# 661    2007-07-25                South Doty Avenue, Chicago, IL, USA
# 777    2007-08-01  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 917    2007-08-01       4200 West 127th Street, Alsip, IL 60803, USA
# 986    2007-08-01  7000 North Moselle Avenue, Chicago, IL 60646, USA
# 1306   2007-08-01             South Avenue L, Chicago, IL 60617, USA
# 1309   2007-08-01             South Avenue L, Chicago, IL 60617, USA
# 1310   2007-08-01             South Avenue L, Chicago, IL 60617, USA
# 1411   2007-08-02        South Stony Island Avenue, Chicago, IL, USA
# ...

# %%
df.shape
# Out:
# (10506, 12)

# %%
totals = df.groupby([df.index, 'Trap', 'Species']).NumMosquitos.sum()
has_nile = df.groupby([df.index, 'Trap', 'Species']).WnvPresent.sum().map(lambda x: int(x > 0))
pd.concat([totals, has_nile], axis=1).reset_index()
# Out:
#        level_0  Trap                 Species  NumMosquitos  WnvPresent
# 0            0  T002  CULEX PIPIENS/RESTUANS             1           0
# 1            1  T002          CULEX RESTUANS             1           0
# 2            2  T007          CULEX RESTUANS             1           0
# 3            3  T015  CULEX PIPIENS/RESTUANS             1           0
# 4            4  T015          CULEX RESTUANS             4           0
# 5            5  T045          CULEX RESTUANS             2           0
# 6            6  T046          CULEX RESTUANS             1           0
# 7            7  T048  CULEX PIPIENS/RESTUANS             1           0
# 8            8  T048          CULEX RESTUANS             2           0
# 9            9  T049          CULEX RESTUANS             1           0
# 10          10  T050  CULEX PIPIENS/RESTUANS             1           0
# 11          11  T054  CULEX PIPIENS/RESTUANS             2           0
# ...

# %%
has_nile
# Out:
#        Trap  Species
# 0      T002  CULEX PIPIENS/RESTUANS    0
# 1      T002  CULEX RESTUANS            0
# 2      T007  CULEX RESTUANS            0
# 3      T015  CULEX PIPIENS/RESTUANS    0
# 4      T015  CULEX RESTUANS            0
# 5      T045  CULEX RESTUANS            0
# 6      T046  CULEX RESTUANS            0
# 7      T048  CULEX PIPIENS/RESTUANS    0
# 8      T048  CULEX RESTUANS            0
# 9      T049  CULEX RESTUANS            0
# 10     T050  CULEX PIPIENS/RESTUANS    0
# 11     T054  CULEX PIPIENS/RESTUANS    0
# 12     T054  CULEX RESTUANS            0
# 13     T086  CULEX PIPIENS/RESTUANS    0
# 14     T086  CULEX RESTUANS            0
# 15     T091  CULEX RESTUANS            0
# 16     T094  CULEX RESTUANS            0
# 17     T096  CULEX RESTUANS            0
# 18     T096  CULEX PIPIENS             0
# 19     T129  CULEX PIPIENS/RESTUANS    0
# 20     T129  CULEX RESTUANS            0
# 21     T143  CULEX PIPIENS/RESTUANS    0
# ...

# %%
t009 = df[df['Trap'] == 'T009']
t009.head()
# Out:
#            Date                                           Address  \
# 50   2007-06-05  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 221  2007-07-02  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 312  2007-07-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 313  2007-07-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 714  2007-07-27  9100 West Higgins Avenue, Chicago, IL 60656, USA
#
#                     Species  Block          Street  Trap  \
# 50           CULEX RESTUANS     91   W HIGGINS AVE  T009
# 221          CULEX RESTUANS     91   W HIGGINS AVE  T009
# 312  CULEX PIPIENS/RESTUANS     91   W HIGGINS AVE  T009
# 313          CULEX RESTUANS     91   W HIGGINS AVE  T009
# 714  CULEX PIPIENS/RESTUANS     91   W HIGGINS AVE  T009
#
#                AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 50   9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827                8
# ...

# %%
t009['Address'].get_values()
# Out:
# array(['9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
#        '9100 West Higgins Avenue, Chicago, IL 60656, USA',
# ...

# %%
t035 = df[df['Trap'] == 'T035']

# %%
t035['Address'].get_values()
# Out:
# array(['3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
#        '3000 South Hoyne Avenue, Chicago, IL 60608, USA',
# ...

# %%
test_df = pd.read_csv('../data/test.csv')

test_df.columns
# Out:
# Index(['Id', 'Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy'],
#       dtype='object')

# %%
test_df['Species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    15359
# CULEX RESTUANS            14670
# CULEX PIPIENS             14521
# CULEX SALINARIUS          14355
# CULEX TERRITANS           14351
# CULEX TARSALIS            14347
# UNSPECIFIED CULEX         14345
# CULEX ERRATICUS           14345
# Name: Species, dtype: int64

# %%
df['Species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    4752
# CULEX RESTUANS            2740
# CULEX PIPIENS             2699
# CULEX TERRITANS            222
# CULEX SALINARIUS            86
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# Name: Species, dtype: int64

# %%
len(test_df['Trap'].value_counts())
# Out:
# 149

# %%
len(df['Trap'].value_counts())
# Out:
# 136

# %%
len(test_df['Date'].value_counts())
# Out:
# 95

# %%
len(df['Date'].value_counts())
# Out:
# 95

# %%
df.columns
# Out:
# Index(['Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
#        'NumMosquitos', 'WnvPresent'],
#       dtype='object')

# %%
# Trying to create a model to predict number of mosquitoes

df.drop('Address', axis=1, inplace=True)
df.drop('Street', axis=1, inplace=True)
df.drop('AddressNumberAndStreet', axis=1, inplace=True)
df.drop('AddressAccuracy', axis=1, inplace=True)

# %%
df.head()
# Out:
#          Date                 Species  Block  Trap   Latitude  Longitude  \
# 0  2007-05-29  CULEX PIPIENS/RESTUANS     41  T002  41.954690 -87.800991
# 1  2007-05-29          CULEX RESTUANS     41  T002  41.954690 -87.800991
# 2  2007-05-29          CULEX RESTUANS     62  T007  41.994991 -87.769279
# 3  2007-05-29  CULEX PIPIENS/RESTUANS     79  T015  41.974089 -87.824812
# 4  2007-05-29          CULEX RESTUANS     79  T015  41.974089 -87.824812
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0

# %%
weather = pd.read_csv('../data/weather.csv')
weather.columns
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg            object
# Depart          object
# DewPoint         int64
# WetBulb         object
# Heat            object
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
weather.drop('Depart', axis=1, inplace=True)

# %%
weather.drop('CodeSum', axis=1, inplace=True)

# %%
weather.drop('Water1', axis=1, inplace=True)

# %%
weather.drop('Depth', axis=1, inplace=True)

# %%
weather.replace(to_replace='M', value=0, inplace=True)

# %%
model = pd.merge(df, weather, on='Date')

# %%
df['Date'] = pd.to_datetime(df['Date'])
weather['Date'] = pd.to_datetime(weather['Date'])

# %%
weather = [weather['Station'] == 1]

# %%
df.shape
# Out:
# (10506, 8)

# %%
model.shape
# Out:
# (21012, 25)
