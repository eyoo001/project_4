# %%
import pandas as pd
from datetime import datetime, timedelta
import numpy as np

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %matplotlib inline

# %%
train = pd.read_csv('../assets/train.csv', parse_dates=[0], index_col=0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10506 entries, 2007-05-29 to 2013-09-26
# Data columns (total 11 columns):
# Address                   10506 non-null object
# Species                   10506 non-null object
# Block                     10506 non-null int64
# Street                    10506 non-null object
# Trap                      10506 non-null object
# AddressNumberAndStreet    10506 non-null object
# Latitude                  10506 non-null float64
# Longitude                 10506 non-null float64
# AddressAccuracy           10506 non-null int64
# NumMosquitos              10506 non-null int64
# WnvPresent                10506 non-null int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 984.9+ KB

# %%
train.groupby('Trap').WnvPresent.sum().sort_values(ascending=False).head()
# Out:
# Trap
# T900    66
# T115    41
# T002    18
# T138    16
# T003    14
# Name: WnvPresent, dtype: int64

# %%
train.groupby('Species').WnvPresent.value_counts()
# Out:
# Species                 WnvPresent
# CULEX ERRATICUS         0                1
# CULEX PIPIENS           0             2459
#                         1              240
# CULEX PIPIENS/RESTUANS  0             4490
#                         1              262
# CULEX RESTUANS          0             2691
#                         1               49
# CULEX SALINARIUS        0               86
# CULEX TARSALIS          0                6
# CULEX TERRITANS         0              222
# Name: WnvPresent, dtype: int64

# %%
spray = pd.read_csv('../assets/spray.csv')

# %%
spray.Date = spray.Date.map(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
spray['year'] = spray.Date.map(lambda x: x.year)

# %%
spray.groupby('year').count()
# Out:
#        Date   Time  Latitude  Longitude
# year
# 2011   2209   1625      2209       2209
# 2013  12626  12626     12626      12626

# %%
def combine_rows(df):
    place_table = df[[
        'Address', 'Block', 'Street', 'Trap', 'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy'
    ]].drop_duplicates().set_index(['Address'])

    totals = df.groupby([df.index, 'Trap', 'Address', 'Species']).NumMosquitos.sum()
    has_nile = df.groupby([df.index, 'Trap', 'Address', 'Species']).WnvPresent.sum().map(lambda x: int(x > 0))
    return pd.concat([totals, has_nile], axis=1).reset_index().merge(place_table.drop('Trap', axis=1), on='Address').set_index('Date')

# %%
#confused how i want to handle the df
def deal_w_stations(df2, weather):
    station1Lat = 41.995
    station1Lon = -87.933
    station2Lat = 41.786
    station2Lon = -87.752

    dist1 = abs((df2.Latitude - station1Lat)*1j + (df2.Longitude - station1Lon))
    dist2 = abs((df2.Latitude - station2Lat)*1j + (df2.Longitude - station2Lon))
    compare = dist1 < dist2
    weather_fields = weather.select_dtypes([float,int]).columns[1:]

    for field in weather_fields:
        df2[field] = df2[field + '_x']*compare + df2[field + '_y']*(1-compare)

    redundant_cols = [name for name in df2.columns if '_' in name]

    return df2.drop(redundant_cols, axis=1)

# %%
weather = pd.read_csv('../assets/ps_weather_processed.csv', parse_dates=[0], index_col=0)\
                .assign(HCDiff = lambda df: df.Heat - df.Cool)\
                .apply(lambda col: col.replace('-',None).ffill().astype(int) if col.name in ['Sunrise', 'Sunset'] else col)\
                .drop(['Heat', 'Cool','isRain'], axis=1)

# %%
shift_dict_default = {
        'Tmin':7,
        'Tmax':7,
        'Tavg':7,
}

# %%
#used in conjunction with apply
def weatherShiftLogic(col, shift_dict=shift_dict_default):
    if col.name in shift_dict:
        return col.shift(shift_dict[col.name])
    else:
        return col.shift(21)

# %%
def merge_weather(df):
    weather = pd.read_csv('../assets/ps_weather_processed.csv', parse_dates=[0], index_col=0)\
                .apply(lambda col: col.replace('-',None).ffill().astype(int) if col.name in ['Sunrise', 'Sunset'] else col)\
                .assign(HCDiff = lambda df: df.Heat - df.Cool, sundiff = lambda df: df.Sunset - df.Sunrise)\
                .drop(['Heat', 'Cool','isRain', 'Sunrise', 'Sunset'], axis=1)

    a = weather.query('Station==1').drop('Station', axis=1).select_dtypes([float,int]).apply(weatherShiftLogic)
    b = weather.query('Station==2').drop('Station', axis=1).select_dtypes([float,int]).apply(weatherShiftLogic)
    df = df.join([a, b]).dropna()
    return deal_w_stations(df, weather)

# %%
def adjust_columns(df2):
    relevant_species = ['CULEX PIPIENS', 'CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS']
    for species in relevant_species:
        df2[species] = df2.Species.map(lambda x: int(x==species))
    df2 = df2.assign(none=df2.Species.map(lambda x: int(x not in relevant_species )), month = df2.index.month, lat2 = df2.Latitude**2, lon2 = df2.Longitude**2, month2 = df2.index.month**2)
    df2 = df2.assign(year = df2.index.year, year2 = df2.index.year**2)
    df2 = df2.select_dtypes([int, float]).drop(['Block', 'AddressAccuracy'], axis=1)
    return df2

# %%
def naivestrap(x, y):
    positive_index = y.reset_index().query('WnvPresent==1').index
    indices = np.random.choice(positive_index, size=len(y)-y.sum())
    return x.copy().iloc[indices,:], y.copy().iloc[indices]

# %%
df2 = combine_rows(train)

# %%
df2 = merge_weather(df2)

# %%
df2 = adjust_columns(df2)

# %% [raw]
# relevant_species = ['CULEX PIPIENS', 'CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS']

# %% [raw]
# for species in relevant_species:
#     df2[species] = df2.Species.map(lambda x: int(x==species))

# %% [markdown]
# ## df2.head()

# %%
print(df2.shape)
print(len(df2)*.3)
df2.head(10)
# Out:
# (8475, 27)
# 2542.5
#             NumMosquitos  WnvPresent   Latitude  Longitude  Tmax  Tmin  Tavg  \
# Date
# 2007-05-29             1           0  41.954690 -87.800991  87.0  55.0  71.0
# 2007-05-29             1           0  41.954690 -87.800991  87.0  55.0  71.0
# 2007-05-29             1           0  41.994991 -87.769279  87.0  55.0  71.0
# 2007-05-29             1           0  41.974089 -87.824812  87.0  55.0  71.0
# 2007-05-29             4           0  41.974089 -87.824812  87.0  55.0  71.0
# 2007-05-29             2           0  41.921600 -87.666455  87.0  60.0  74.0
# 2007-05-29             1           0  41.891118 -87.654491  87.0  60.0  74.0
# 2007-05-29             1           0  41.867108 -87.654224  87.0  60.0  74.0
# 2007-05-29             2           0  41.867108 -87.654224  87.0  60.0  74.0
# 2007-05-29             1           0  41.896282 -87.655232  87.0  60.0  74.0
#
#             DewPoint  WetBulb  PrecipTotal   ...     CULEX PIPIENS  \
# Date                                         ...
# 2007-05-29      58.0     62.0        0.000   ...                 0
# 2007-05-29      58.0     62.0        0.000   ...                 0
# 2007-05-29      58.0     62.0        0.000   ...                 0
# 2007-05-29      58.0     62.0        0.000   ...                 0
# 2007-05-29      58.0     62.0        0.000   ...                 0
# 2007-05-29      57.0     63.0        0.005   ...                 0
# 2007-05-29      57.0     63.0        0.005   ...                 0
# 2007-05-29      57.0     63.0        0.005   ...                 0
# 2007-05-29      57.0     63.0        0.005   ...                 0
# 2007-05-29      57.0     63.0        0.005   ...                 0
#
#             CULEX PIPIENS/RESTUANS  CULEX RESTUANS  none  month         lat2  \
# Date
# 2007-05-29                       1               0     0      5  1760.196013
# 2007-05-29                       0               1     0      5  1760.196013
# 2007-05-29                       0               1     0      5  1763.579269
# 2007-05-29                       1               0     0      5  1761.824147
# 2007-05-29                       0               1     0      5  1761.824147
# 2007-05-29                       0               1     0      5  1757.420547
# 2007-05-29                       0               1     0      5  1754.865767
# 2007-05-29                       1               0     0      5  1752.854732
# 2007-05-29                       0               1     0      5  1752.854732
# 2007-05-29                       0               1     0      5  1755.298445
#
#                    lon2  month2  year    year2
# Date
# 2007-05-29  7709.014021      25  2007  4028049
# 2007-05-29  7709.014021      25  2007  4028049
# 2007-05-29  7703.446336      25  2007  4028049
# 2007-05-29  7713.197603      25  2007  4028049
# 2007-05-29  7713.197603      25  2007  4028049
# 2007-05-29  7685.407332      25  2007  4028049
# 2007-05-29  7683.309792      25  2007  4028049
# 2007-05-29  7683.262985      25  2007  4028049
# 2007-05-29  7683.262985      25  2007  4028049
# 2007-05-29  7683.439697      25  2007  4028049
#
# [10 rows x 27 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = df2.drop(['WnvPresent','NumMosquitos'], axis=1)
y = df2.WnvPresent

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3)

# %%
xtrain.head().T
# Out:
# Date                      2009-09-14    2009-09-17    2009-07-17  \
# Latitude                4.167862e+01  4.189112e+01  4.182254e+01
# Longitude              -8.755931e+01 -8.765449e+01 -8.766634e+01
# Tmax                    7.700000e+01  8.000000e+01  8.400000e+01
# Tmin                    6.300000e+01  6.500000e+01  6.700000e+01
# Tavg                    7.000000e+01  7.300000e+01  7.600000e+01
# DewPoint                5.700000e+01  6.100000e+01  6.100000e+01
# WetBulb                 6.200000e+01  6.300000e+01  6.700000e+01
# PrecipTotal             0.000000e+00  1.190000e+00  0.000000e+00
# StnPressure             2.947000e+01  2.941000e+01  2.920000e+01
# SeaLevel                3.012000e+01  3.007000e+01  2.983000e+01
# ResultSpeed             5.000000e+00  1.070000e+01  6.400000e+00
# ResultDir               2.100000e+01  8.000000e+00  4.000000e+00
# AvgSpeed                5.700000e+00  1.100000e+01  8.000000e+00
# HCDiff                 -3.000000e+00  0.000000e+00 -1.400000e+01
# sundiff                 1.331000e+03  1.323000e+03  1.513000e+03
# CULEX PIPIENS           0.000000e+00  0.000000e+00  0.000000e+00
# CULEX PIPIENS/RESTUANS  0.000000e+00  0.000000e+00  1.000000e+00
# CULEX RESTUANS          1.000000e+00  1.000000e+00  0.000000e+00
# none                    0.000000e+00  0.000000e+00  0.000000e+00
# month                   9.000000e+00  9.000000e+00  7.000000e+00
# lat2                    1.737107e+03  1.754866e+03  1.749125e+03
# lon2                    7.666632e+03  7.683310e+03  7.685388e+03
# month2                  8.100000e+01  8.100000e+01  4.900000e+01
# year                    2.009000e+03  2.009000e+03  2.009000e+03
# year2                   4.036081e+06  4.036081e+06  4.036081e+06
# predicted_proba         9.312844e-02  3.197858e-02  3.549452e-01
#
# Date                      2007-09-12    2013-09-12
# Latitude                4.177285e+01  4.177166e+01
# Longitude              -8.774003e+01 -8.770305e+01
# Tmax                    9.100000e+01  7.400000e+01
# Tmin                    7.200000e+01  6.500000e+01
# Tavg                    8.200000e+01  7.000000e+01
# DewPoint                7.000000e+01  6.600000e+01
# WetBulb                 7.300000e+01  6.800000e+01
# PrecipTotal             8.800000e-01  3.600000e-01
# StnPressure             2.929000e+01  2.942000e+01
# SeaLevel                2.993000e+01  3.005000e+01
# ResultSpeed             5.100000e+00  2.500000e+00
# ResultDir               2.100000e+01  2.400000e+01
# AvgSpeed                8.400000e+00  7.000000e+00
# HCDiff                 -1.500000e+01 -8.000000e+00
# sundiff                 1.337000e+03  1.337000e+03
# CULEX PIPIENS           1.000000e+00  0.000000e+00
# CULEX PIPIENS/RESTUANS  0.000000e+00  0.000000e+00
# CULEX RESTUANS          0.000000e+00  1.000000e+00
# none                    0.000000e+00  0.000000e+00
# month                   9.000000e+00  9.000000e+00
# lat2                    1.744971e+03  1.744872e+03
# lon2                    7.698313e+03  7.691824e+03
# month2                  8.100000e+01  8.100000e+01
# year                    2.007000e+03  2.013000e+03
# year2                   4.028049e+06  4.052169e+06
# predicted_proba         6.835760e-01  3.788976e-01

# %%
ytest.sum()
print(len(ytest))
ytest
# Out:
# 2543
# Date
# 2011-07-15    0
# 2007-08-21    0
# 2013-06-27    0
# 2007-06-05    0
# 2011-08-19    0
# 2013-06-21    0
# 2011-08-12    0
# 2009-07-10    0
# 2013-08-29    0
# 2013-08-08    0
# 2009-06-12    0
# 2011-07-29    0
# 2011-08-12    0
# 2009-07-27    0
# 2009-07-31    0
# 2007-09-04    1
# 2013-08-01    0
# 2009-09-17    0
# 2007-09-12    0
# 2007-09-24    0
# 2009-06-19    0
# 2009-07-10    0
# 2007-07-27    0
# 2007-09-18    0
# 2011-07-15    0
# 2013-08-01    0
# 2009-06-26    0
# 2007-10-04    0
# 2011-09-23    0
# 2007-09-24    0
#              ..
# 2007-08-21    0
# 2007-08-21    0
# 2007-08-07    0
# 2011-07-11    0
# 2011-09-16    0
# 2007-09-04    0
# 2007-10-04    0
# 2009-08-07    0
# 2007-07-18    0
# 2007-08-24    0
# 2009-06-19    0
# 2009-08-13    0
# 2007-08-15    0
# 2011-07-11    0
# 2009-08-25    0
# 2007-07-02    0
# 2009-06-12    0
# 2011-07-25    0
# 2009-09-25    0
# 2009-08-25    1
# 2009-09-14    0
# 2007-07-25    1
# 2013-08-01    0
# 2013-06-21    0
# 2009-06-02    0
# 2009-06-26    0
# 2007-06-26    0
# 2007-08-21    0
# 2009-09-03    0
# 2007-07-25    0
# Name: WnvPresent, Length: 2543, dtype: int64

# %%
xtrainint, ytrainint = naivestrap(xtrain, ytrain)
xtrain = pd.concat([xtrain, xtrainint])
ytrain = pd.concat([ytrain, ytrainint])

# %% [raw]
# x = df2.drop(['WnvPresent','NumMosquitos'], axis=1)
# y = df2.WnvPresent
# tsplit = TimeSeriesSplit(n_splits=7)
# forests = []
#
# for train_index, test_index in tsplit.split(x):
#     xtrain, xtest, ytrain, ytest = x.iloc[train_index,:], x.iloc[test_index,:], y.iloc[train_index], y.iloc[test_index]
#     model = RandomForestClassifier(n_estimators=50, max_depth=10, class_weight=None)
#     forests.append((model.fit(xtrain, ytrain),model.score(xtest, ytest)))
#
# model = sorted(forests, key=lambda x: x[1], reverse=True)[0][0]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score

# %%
scaler = StandardScaler()

# %%
xtrain_sc = scaler.fit_transform(xtrain)
xtest_sc = scaler.transform(xtest)

# %%
logreg = LogisticRegression(C=0.05, penalty='l2')
logreg.fit(xtrain_sc, ytrain)
logreg.score(xtest_sc, ytest)
# Out:
# 0.6716476602438065

# %%
roc_auc_score(ytrain, [proba[1] for proba in logreg.predict_proba(xtrain_sc)])
# Out:
# 0.8136382410484333

# %%
roc_auc_score(ytest, [proba[1] for proba in logreg.predict_proba(xtest_sc)])
# Out:
# 0.7990981878032473

# %% [markdown]
# ## Checking spatial prediction probabilities:

# %%
logreg.classes_
# Out:
# array([0, 1])

# %%
probas_logreg = logreg.predict_proba(xtest_sc)

# %%
print(probas_logreg.shape)
len(probas_logreg)
# Out:
# (2543, 2)
# 2543

# %%
print(xtest_sc.shape)
xtest_sc[6]
# Out:
# (2543, 25)
# array([-1.03817509,  1.67717729,  0.3070141 ,  0.84371521,  0.56871344,
#         1.49647901,  1.54317466,  0.05339   , -0.71020798, -0.98356677,
#        -0.70888241, -0.62798564,  0.37144128, -0.74906557,  0.52193946,
#        -0.66696883,  1.03964982, -0.49002502, -0.13507152,  0.09474041,
#        -1.03826809, -1.67613009,  0.03875618,  0.41771024,  0.41716949])

# %%
y_proba = [row[1] for row in logreg.predict_proba(xtrain_sc)]
len(y_proba)
# Out:
# 11553

# %%
xtrain.shape[0]
# Out:
# 11553

# %%
xtrain['predicted_proba'] = y_proba

# %%
xtrain['y']=ytrain

# %%
xtrain.head()
# Out:
#              Latitude  Longitude  Tmax  Tmin  Tavg  DewPoint  WetBulb  \
# Date
# 2009-09-14  41.678618 -87.559308  77.0  63.0  70.0      57.0     62.0
# 2009-09-17  41.891118 -87.654491  80.0  65.0  73.0      61.0     63.0
# 2009-07-17  41.822536 -87.666343  84.0  67.0  76.0      61.0     67.0
# 2007-09-12  41.772846 -87.740029  91.0  72.0  82.0      70.0     73.0
# 2013-09-12  41.771660 -87.703047  74.0  65.0  70.0      66.0     68.0
#
#             PrecipTotal  StnPressure  SeaLevel ...  CULEX RESTUANS  none  \
# Date                                           ...
# 2009-09-14         0.00        29.47     30.12 ...               1     0
# 2009-09-17         1.19        29.41     30.07 ...               1     0
# 2009-07-17         0.00        29.20     29.83 ...               0     0
# 2007-09-12         0.88        29.29     29.93 ...               0     0
# 2013-09-12         0.36        29.42     30.05 ...               1     0
#
#             month         lat2         lon2  month2  year    year2  \
# Date
# 2009-09-14      9  1737.107198  7666.632417      81  2009  4036081
# 2009-09-17      9  1754.865767  7683.309792      81  2009  4036081
# 2009-07-17      7  1749.124517  7685.387695      49  2009  4036081
# 2007-09-12      9  1744.970663  7698.312689      81  2007  4028049
# 2013-09-12      9  1744.871579  7691.824453      81  2013  4052169
#
#             predicted_proba  y
# Date
# 2009-09-14         0.093128  0
# 2009-09-17         0.031979  0
# 2009-07-17         0.354945  0
# 2007-09-12         0.683576  0
# 2013-09-12         0.378898  0
#
# [5 rows x 27 columns]

# %%
xtrain[xtrain.y>=1]
# Out:
#              Latitude  Longitude  Tmax  Tmin  Tavg  DewPoint  WetBulb  \
# Date
# 2007-08-21         0.721944  1
# 2013-08-08         0.969256  1
# 2007-08-01         0.659491  1
# 2013-08-22         0.614510  1
# 2013-06-28         0.081701  1
# 2013-08-08         0.929475  1
# 2013-08-22         0.604827  1
# 2013-08-08         0.736193  1
# 2013-08-08         0.945034  1
# 2013-08-15         0.890663  1
# 2007-08-15         0.779414  1
# 2013-08-08         0.945025  1
# 2007-09-04         0.636584  1
# 2007-08-15         0.669881  1
# 2013-08-29         0.826527  1
# 2007-08-15         0.811134  1
# 2013-09-19         0.614335  1
# 2007-08-22         0.651930  1
# 2013-08-08         0.947919  1
# 2011-08-12         0.921633  1
# 2007-08-22         0.775118  1
# 2013-08-22         0.788233  1
# 2013-08-15         0.867127  1
# 2013-08-15         0.447285  1
# ...                     ... ..
# 2013-08-22         0.657129  1
# 2007-08-01         0.494384  1
# 2013-08-22         0.717477  1
# 2007-08-24         0.727246  1
# 2007-08-24         0.748830  1
# 2013-09-26         0.494208  1
# 2013-08-15         0.864300  1
# 2013-08-29         0.676020  1
# 2013-08-08         0.949715  1
# 2013-08-15         0.829397  1
# 2013-09-12         0.573218  1
# 2013-09-06         0.841327  1
# 2007-09-04         0.636584  1
# 2013-08-15         0.447285  1
# 2007-07-18         0.198274  1
# 2009-08-25         0.805523  1
# 2007-08-16         0.544730  1
# 2013-08-22         0.614510  1
# 2007-08-22         0.734796  1
# 2009-08-25         0.767862  1
# 2007-08-22         0.695113  1
# 2011-07-25         0.861749  1
# 2007-08-07         0.797324  1
# 2007-08-21         0.705186  1
# 2007-09-04         0.636584  1
# 2013-09-06         0.682527  1
# 2011-08-05         0.936889  1
# 2007-08-15         0.766627  1
# 2007-08-08         0.544930  1
# 2007-08-09         0.533540  1
#
# [5932 rows x 27 columns]

# %%
xtrain[(xtrain['predicted_proba']<=.5) & (xtrain.index>='2013-08-18') & (xtrain.index<='2013-08-24') & (xtrain.y==0)]
# Out:
#              Latitude  Longitude  Tmax  Tmin  Tavg  DewPoint  WetBulb  \
# Date
# 2013-08-22  41.867108 -87.654224  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.673408 -87.599862  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.868077 -87.666901  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.825610 -87.726549  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.822536 -87.666343  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.720848 -87.666014  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.899230 -87.716788  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.974689 -87.890615  75.0  55.0  65.0      57.0     62.0
# 2013-08-22  41.801498 -87.763416  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.921965 -87.632085  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.659112 -87.538693  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.743402 -87.731435  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.906638 -87.701431  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.728495 -87.600963  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.800737 -87.711880  74.0  57.0  66.0      54.0     62.0
# 2013-08-22  41.992478 -87.862995  75.0  55.0  65.0      57.0     62.0
#
#             PrecipTotal  StnPressure  SeaLevel ...  CULEX RESTUANS  none  \
# Date                                           ...
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.23     29.95 ...               0     1
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.29     29.95 ...               1     0
# 2013-08-22          0.0        29.23     29.95 ...               1     0
#
#             month         lat2         lon2  month2  year    year2  \
# Date
# 2013-08-22      8  1752.854732  7683.262985      64  2013  4052169
# 2013-08-22      8  1736.672934  7673.735822      64  2013  4052169
# 2013-08-22      8  1752.935872  7685.485531      64  2013  4052169
# 2013-08-22      8  1749.381652  7695.947399      64  2013  4052169
# 2013-08-22      8  1749.124517  7685.387695      64  2013  4052169
# 2013-08-22      8  1740.629158  7685.330011      64  2013  4052169
# 2013-08-22      8  1755.545475  7694.234897      64  2013  4052169
# 2013-08-22      8  1761.874517  7724.760205      64  2013  4052169
# 2013-08-22      8  1747.365235  7702.417188      64  2013  4052169
# 2013-08-22      8  1757.451149  7679.382321      64  2013  4052169
# 2013-08-22      8  1735.481613  7663.022772      64  2013  4052169
# 2013-08-22      8  1742.511611  7696.804687      64  2013  4052169
# 2013-08-22      8  1756.166308  7691.540999      64  2013  4052169
# 2013-08-22      8  1741.267295  7673.928719      64  2013  4052169
# 2013-08-22      8  1747.301614  7693.373893      64  2013  4052169
# 2013-08-22      8  1763.368209  7719.905890      64  2013  4052169
#
#             predicted_proba  y
# Date
# 2013-08-22         0.333042  0
# 2013-08-22         0.400431  0
# 2013-08-22         0.344986  0
# 2013-08-22         0.435039  0
# 2013-08-22         0.373149  0
# 2013-08-22         0.439902  0
# 2013-08-22         0.376050  0
# 2013-08-22         0.025098  0
# 2013-08-22         0.491902  0
# 2013-08-22         0.280356  0
# 2013-08-22         0.346506  0
# 2013-08-22         0.496384  0
# 2013-08-22         0.355605  0
# 2013-08-22         0.365951  0
# 2013-08-22         0.435876  0
# 2013-08-22         0.480855  0
#
# [16 rows x 27 columns]

# %%
128/(128+713)
# Out:
# 0.15219976218787157

# %% [markdown]
# ## Plot True-positives and False-Positives:

# %%
mapdata = np.loadtxt("../assets/mapdata_copyright_openstreetmap_contributors.txt")

# %%
fig=plt.figure(figsize=(7,12))
plt.imshow(mapdata, cmap = plt.get_cmap('gray'), extent = (-88, -87.5, 41.6, 42.05),
           aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1])
d_w = '2013-07-19'
p_proba = 0.65
p_rest = (xtrain['CULEX RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']>=p_proba) & (xtrain.y==1)
p_pip  = (xtrain['CULEX PIPIENS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']>=p_proba) & (xtrain.y==1)
p_mix  = (xtrain['CULEX PIPIENS/RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']>=p_proba) & (xtrain.y==1)
n_rest = (xtrain['CULEX RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']<=1-p_proba) & (xtrain.y==1)
n_pip  = (xtrain['CULEX PIPIENS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']<=1-p_proba) & (xtrain.y==1)
n_mix  = (xtrain['CULEX PIPIENS/RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']<=1-p_proba) & (xtrain.y==1)


plt.scatter(xtrain[p_rest]['Longitude'],
            xtrain[p_rest]['Latitude'],marker='o',facecolors='none',
            edgecolors='g', label='Restuans-tp',s=xtrain[p_rest]['predicted_proba']*50)
plt.scatter(xtrain[p_pip]['Longitude'],
            xtrain[p_pip]['Latitude'],marker='o',edgecolors='g',label='Pipiens-tp',
            facecolors='none',s=xtrain[p_pip]['predicted_proba']*50)
plt.scatter(xtrain[p_mix]['Longitude'],
            xtrain[p_mix]['Latitude'],marker='o',edgecolors='g',label='Pipiens/Restuans-tp', 
            facecolors='none', s=xtrain[p_mix]['predicted_proba']*50)

plt.scatter(xtrain[n_rest]['Longitude'],
            xtrain[n_rest]['Latitude'],marker='x',
            color='r', label='Restuans-fn',s=xtrain[n_rest]['predicted_proba']*50)
plt.scatter(xtrain[n_pip]['Longitude'],
            xtrain[n_pip]['Latitude'],marker='x',color='r',label='Pipiens-fn',
            s=xtrain[n_pip]['predicted_proba']*50)
plt.scatter(xtrain[n_mix]['Longitude'],
            xtrain[n_mix]['Latitude'],marker='x',color='r',label='Pipiens/Restuans-fn',
            s=xtrain[n_mix]['predicted_proba']*50)

plt.title('Predicted-probas_.65/.35, Week-29 (of 19-Jul-2013)')
plt.legend()

# %%
fig=plt.figure(figsize=(7,12))
plt.imshow(mapdata, cmap = plt.get_cmap('gray'), extent = (-88, -87.5, 41.6, 42.05),
           aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1])
d_w = '2013-07-19'
p_proba = 0.65
p_rest = (xtrain['CULEX RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']>=p_proba) & (xtrain.y==0)
p_pip  = (xtrain['CULEX PIPIENS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']>=p_proba) & (xtrain.y==0)
p_mix  = (xtrain['CULEX PIPIENS/RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']>=p_proba) & (xtrain.y==0)
n_rest = (xtrain['CULEX RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']<=1-p_proba) & (xtrain.y==0)
n_pip  = (xtrain['CULEX PIPIENS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']<=1-p_proba) & (xtrain.y==0)
n_mix  = (xtrain['CULEX PIPIENS/RESTUANS']==1) & (xtrain.index==d_w) & (xtrain['predicted_proba']<=1-p_proba) & (xtrain.y==0)


plt.scatter(xtrain[p_rest]['Longitude'],
            xtrain[p_rest]['Latitude'],marker='o',facecolors='none',
            edgecolors='b', label='Restuans-fp',s=xtrain[p_rest]['predicted_proba']*50)
plt.scatter(xtrain[p_pip]['Longitude'],
            xtrain[p_pip]['Latitude'],marker='o',edgecolors='b',label='Pipiens-fp',
            facecolors='none',s=xtrain[p_pip]['predicted_proba']*50)
plt.scatter(xtrain[p_mix]['Longitude'],
            xtrain[p_mix]['Latitude'],marker='o',edgecolors='b',label='Pipiens/Restuans-fp', 
            facecolors='none', s=xtrain[p_mix]['predicted_proba']*50)

plt.scatter(xtrain[n_rest]['Longitude'],
            xtrain[n_rest]['Latitude'],marker='x',
            color='r', label='Restuans-tn',s=xtrain[n_rest]['predicted_proba']*50)
plt.scatter(xtrain[n_pip]['Longitude'],
            xtrain[n_pip]['Latitude'],marker='x',color='r',label='Pipiens-tn',
            s=xtrain[n_pip]['predicted_proba']*50)
plt.scatter(xtrain[n_mix]['Longitude'],
            xtrain[n_mix]['Latitude'],marker='x',color='r',label='Pipiens/Restuans-tn',
            s=xtrain[n_mix]['predicted_proba']*50)

plt.title('Predicted-probas_.65/.35, Week-29 (of 19-Jul-2013)')
plt.legend()

# %%
names = list(x.columns)
names.append('predicted_proba')

# %%
xtrain.values

# %%
sorted(list(zip(x.columns, logreg.coef_[0])), key=lambda x: x[1])

# %%
model_lr = logreg

# %%
import seaborn as sns

# %%
df2.info()

# %%
df2.corr().WnvPresent

# %%
test = pd.read_csv('../assets/test.csv', parse_dates=[1], index_col=1)
test = merge_weather(test)
test = adjust_columns(test)
test = test.drop('Id', axis=1)

# %%
test = scaler.transform(test)

# %% [markdown]
# submission = pd.DataFrame([predictions[1] for predictions in model_lr.predict_proba(test)], columns=['WnvPresent'])
# submission = submission.reset_index().rename({'index':'Id'}, axis=1)
# submission.loc[:,'Id'] = submission.Id + 1
# submission = submission.set_index('Id')
# submission.to_csv('submissionlog.csv')
